# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root / "src"))

# %%
import pandas as pd
from mmm_quality_checks.pipeline import run_quality_checks

df = pd.read_csv("../data/MMM_dummy_outputs.csv")
result = run_quality_checks(df, na_in_missing_data=True)

result

# %% [markdown]
# # Vizualization

# %%
from mmm_quality_checks.visualizations import *

fig = build_summary_cards(result)
fig.show()

# %%
fig = build_parameter_range_chart(result)
fig.show()

# %%
fig = build_flag_heatmap(result)
fig.show()

# %%
fig = build_contribution_bar_chart(result)
fig.show()

# %%
fig = build_elasticity_vs_contribution_scatter(result)
fig.show()
