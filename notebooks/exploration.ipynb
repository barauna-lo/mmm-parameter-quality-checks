# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root / "src"))

# %%
import pandas as pd
from mmm_quality_checks.pipeline import run_quality_checks

df = pd.read_csv("../data/MMM_dummy_outputs.csv")
result = run_quality_checks(df, na_in_missing_data=True)

result
# Out:
#        Channel  Coefficient  p_value Elasticity  contribution_pct  \
# 0  Google PMax        0.120    0.030        1.2             15.00
# 1  Paid Social        0.085    0.150        0.9             13.00
# 2          CTV        0.250    0.060        3.4             12.00
# 3        Radio        0.040    0.080       -0.2              2.00
# 4      Display        0.030    0.090        0.3              0.80
# 5          OOH        0.060    0.020        1.1              0.99
# 6    Affiliate        0.070    0.100        0.5             11.00
# 7   Influencer        0.055    0.101          3              9.00
# 8         DOOH        0.120      NaN       high              2.00
# 9      Open TV        0.250    0.030      sixty              5.00
#
#    adstock_half_life Extra_Column  \
# 0               14.0          NaN
# 1               10.0          NaN
# 2               35.0          NaN
# 3                7.0   unexpected
# 4               21.0          NaN
# 5                0.5          NaN
# 6              150.0   unexpected
# 7                1.1   unexpected
# 8                1.0   unexpected
# 9               35.0   unexpected
#
#                                    validation_errors  low_significance_flag  \
# 0                                               None                  False
# 1                                               None                   True
# 2                                               None                  False
# 3                                               None                  False
# 4                                               None                  False
# 5                                               None                  False
# 6                                               None                  False
# 7                                               None                   True
# 8  p_value: value is missing; Elasticity: format ...                   <NA>
# 9                Elasticity: format is not numerical                  False
#
#    suspicious_elasticity_flag  over_dominant_contribution_flag  \
# 0                       False                            False
# 1                       False                            False
# 2                        True                            False
# 3                        True                            False
# 4                       False                             True
# 5                       False                             True
# 6                       False                            False
# 7                       False                            False
# 8                        <NA>                            False
# 9                        <NA>                            False
#
#    unrealistic_adstock_flag  has_any_issue
# 0                     False          False
# 1                     False           True
# 2                     False           True
# 3                     False           True
# 4                     False           True
# 5                      True           True
# 6                     False          False
# 7                     False           True
# 8                     False           True
# 9                     False           True
